# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
age = [14, 15, 16, 17, 18, 19]

age_dict = {"14":0, "15":1, "16":2, "17":3, "18":4, "19":5}

# %%
basketball_player = [4, 6, 3, 9, 8, 7, 3, 7]

volleyball_player = [5, 7, 3, 6, 9, 8, 6, 4]

# %%
abilities = {

    "Speed": 6,

    "Strength": 7,

    "Endurance": 5,

    "Agility": 6,

    "Ball Handling": 8,

    "Passing": 9,

    "Tackling": 7
}

# %%
score_matrix = np.array([
    [12, 18, 19, 14],
    [15, 12, 16, 16],
    [18, 16, 13, 15],
    [14, 16, 23, 21],
    [17, 16, 25, 24],
    [16, 14, 11, 22],
])

members_matrix = np.array([
    [1, 2, 8, 9],
    [4, 8, 0, 5],
    [1, 9, 0, 2],
    [6, 9, 4, 7],
    [9, 1, 2, 3],
    [2, 2, 2, 8]
])

abilities_matrix = np.array([
    [6, 9, 4, 6],
    [5, 9, 9, 5],
    [7, 8, 5, 9],
    [8, 5, 6, 3],
    [8, 7, 4, 7],
    [3, 8, 1, 0]  
])

skills_matrix = np.array([
    [25, 22, 23, 26],
    [25, 24, 24, 29],
    [28, 26, 23, 24],
    [13, 16, 12, 17],
    [16, 23, 28, 30],
    [15, 26, 23, 27]
])

# %%
# Bar Graph

plt.bar(range(len(members_matrix[4])), members_matrix[4])
plt.title("Player at the age of 18")
plt.xlabel("Categories")
plt.ylabel("member")

plt.show()

# %%
plt.plot(score_matrix[5], marker='o')
plt.title("Scores of the players")
plt.xlabel("Categories")
plt.ylabel("scores")
plt.show()

# %%
plt.scatter(range(len(abilities_matrix[3])), abilities_matrix[3])
plt.title("Abilities of the player (19)")
plt.xlabel("Categories")
plt.ylabel("Abilities")

plt.show()

# %%
plt.imshow(skills_matrix, cmap='Blues_r')
plt.title("skills of players based on their age")
plt.yticks(range(len(age)), age) 
plt.colorbar()


plt.show()
